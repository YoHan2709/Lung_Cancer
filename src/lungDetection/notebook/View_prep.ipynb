# %%
import matplotlib
# %matplotlib inline
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np

# %%
def take_preprocess_img(name):
    path_load = '../work/' + name + '/' + name + '_clean.npy'
    img = np.load(path_load)
    return img

# %%
img = take_preprocess_img('PAT001DSB')

# %%
img.shape
# Out:
# (1, 305, 217, 304)

# %%
ax = plt.subplot(1,1,1)
plt.imshow(img[0,150],'gray')
plt.axis('off')
# Out:
# (-0.5, 303.5, 216.5, -0.5)
